# %% [markdown]
# <a href="https://colab.research.google.com/github/linggaaradhanas22/FinancialSentimentAnalysis_TimTwoOne/blob/main/Project_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Persiapan *Library* dan *Environment*

# %%
import pandas as pd
from google.colab import drive

# %% [markdown]
#  # Praproses Data
#
#  ## Standardisasi Data
#  Di proses ini, ketiga *dataset* yang digunakan (`finance dataset - Sheet 1.csv`, `financial_news_mt.csv`, dan `financial_news_mt2.csv`) akan distandardisasi sehingga memiliki format yang sama. Kode di bawah menunjukkan prosesnya.

# %%
# Memuat konten drive
drive.mount('/content/drive')

base_path = '/content/drive/MyDrive/TimTwoOne Finance AI/For_Github/' # Kode ini menyesuaikan lokasi persis file dataset

# Menyimpan path dataset ke variabel
file_path_1 = base_path + 'finance dataset - Sheet1.csv'
file_path_2 = base_path + 'financial_news_mt.csv'
file_path_3 = base_path + 'financial_news_mt_2.csv'

# Memuat dataset ke Pandas DataFrame
data_1 = pd.read_csv(file_path_1)
data_2 = pd.read_csv(file_path_2)
data_3 = pd.read_csv(file_path_3)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Melihat struktur dataset pertama
data_1.head()
# Out:
#          date label   category  \
# 0  25/12/2021    up  Finansial
# 1  27/12/2021    up  Finansial
# 2  30/12/2021  down  Finansial
# 3  31/12/2021  down  Finansial
# 4    3/1/2022  down  Finansial
#
#                                                title  \
# 0                 Santa Claus: Let’s Go To The Moon!
# 1           BUMN: Lapor, 120 Ton Kopi OTW Mesir Pak!
# 2       Yogyakarta alternatif Bali dalam pariwisata?
# 3  Tutup tahun bagi para e-commerce: Banyak Lemba...
# 4  Pemerintah: Batu bara jangan keluar negeri dul...
#
#                                                 mksa  \
# 0  Intinya… di penghujung tahun tepatnya 7 hari s...
# 1  Intinya… PT Perusahaan Perdagangan Indonesia/P...
# 2  Intinya… selama pandemi pariwisata Bali tidak ...
# 3  intinya… cukup banyak yang terjadi di dunia e-...
# 4  Intinya… Pemerintah melarang ekspor batu bara ...
#
#                                              content harga yang dicari
# ...

# %%
# Melihat struktur dataset kedua
data_2.head()
# Out:
#    Unnamed: 0     label                                            en_text  \
# 0           2  negative  The international electronic industry company ...
# 1           3  positive  With the new production plant the company woul...
# 2           4  positive  According to the company 's updated strategy f...
# 3           5  positive  FINANCING OF ASPOCOMP 'S GROWTH Aspocomp is ag...
# 4           6  positive  For the last quarter of 2010 , Componenta 's n...
#
#                                              id_text
# 0  Perusahaan industri elektronik internasional E...
# 1  Dengan pabrik produksi baru, perusahaan akan m...
# 2  Sesuai dengan strategi terbaru perusahaan untu...
# 3  PEMBIAYAAN UNTUK PERTUMBUHAN ASPOCOMP Aspocomp...
# 4  Untuk kuartal terakhir tahun 2010, penjualan b...

# %%
# Melihat struktur dataset ketiga
data_3.head()
# Out:
#   label                                            content
# 0    up  Investor miliarder dan bintang Shark Tank Mark...
# 1    up  Pengacara Jarrett Adams baru-baru ini membantu...
# 2    up  Hutan Hujan Amazon terkenal di seluruh dunia s...
# 3    up  Polisi Newark: Tidak ada petugas yang melepask...
# 4    up  I 1970 dÃ¸de det 560 mennesker i den norske tr...

# %%
# Melakukan penyamarataan label sentimen sehingga ketiga dataset memiliki label up untuk sentimen positif dan down untuk sentimen negatif
